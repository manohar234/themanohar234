# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd #Data Manipulation
import seaborn as sns #Data Visualization
import numpy as np #Numerical Python

# %%
df = pd.read_csv("Company_Data.csv")
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
df["Sales"].min(), df["Sales"].max() ,df["Sales"].mean()
# Out:
# (0.0, 16.27, 7.496325000000001)

# %%
dq=df[df["Sales"]<=5]
dq
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 4     4.15        141      64            3         340    128       Bad   38
# 9     4.69        132     113            0         131    124    Medium   76
# 12    3.98        122      35            2         393    136    Medium   62
# 28    2.99        103      74            0         359     97       Bad   55
# 34    2.67        115      54            0         406    128    Medium   42
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 358   4.17        123      96           10          71    118       Bad   69
# 359   3.13        130      62           11         396    130       Bad   66
# 381   3.90        124      65           21         496    151       Bad   77
# 382   4.95        121      28           19         315    121    Medium   66
# 392   4.53        129      42           13         315    130       Bad   34
#
#      Education Urban   US
# ...

# %% [markdown]
# # eda and visulization

# %%
sale=df.assign(ysales=pd.cut(df['Sales'],bins=[0,9,20],labels=['low','high'])) #to convert numerical data into categorical
# values we use .cut , bins shows range

# %%
sale
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US ysales
# ...

# %%
y=sale["ysales"]

# %%
y
# Out:
# 0      high
# 1      high
# 2      high
# 3       low
# 4       low
#        ...
# 395    high
# 396     low
# 397     low
# 398     low
# 399    high
# Name: ysales, Length: 400, dtype: category
# Categories (2, object): ['low' < 'high']

# %% [markdown]
# # eda

# %%
sale.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# ysales         1
# dtype: int64

# %%
sns.heatmap(sale.isnull(),cmap="cubehelix") #Matrix plotting
# Out:
# <AxesSubplot:>

# %%
miss_df =sale[sale["ysales"].isnull()]
miss_df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 174    0.0        139      24            0         358    185    Medium   79
#
#      Education Urban  US ysales
# 174         15    No  No    NaN

# %%
sale= sale.drop([174],axis=0) #0-row, 1-column

# %%
sale
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US ysales
# ...

# %%
sale.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# ysales         0
# dtype: int64

# %%
# One-Hot Encoding of categrical variables
sale=pd.get_dummies(sale,columns=['ShelveLoc'])
sale
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
# ...

# %%
sale["Urban"] = sale["Urban"].replace({"Yes":1,"No":0}) #labeling: LabelEncoder
sale["US"] = sale["US"].replace({"Yes":1,"No":0}) #labeling: LabelEncoder

# %%
sale
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
# ...

# %%
df.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
#
#                   Age  Education
# Sales       -0.231815  -0.051955
# CompPrice   -0.100239   0.025197
# Income      -0.004670  -0.056855
# Advertising -0.004557  -0.033594
# Population  -0.042663  -0.106378
# Price       -0.102177   0.011747
# ...

# %%
sale["ysales"] = sale["ysales"].replace({"high":1,"low":0}) # label encoding

# %%
sale
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
# ...

# %%
dff=pd.concat([sale.iloc[:,1:10],sale.iloc[:,11:],sale.iloc[:,10]],axis=1) # rearranging the columns
dff
# Out:
#      CompPrice  Income  Advertising  Population  Price  Age  Education  Urban  \
# 0          138      73           11         276    120   42         17      1
# 1          111      48           16         260     83   65         10      1
# 2          113      35           10         269     80   59         12      1
# 3          117     100            4         466     97   55         14      1
# 4          141      64            3         340    128   38         13      1
# ..         ...     ...          ...         ...    ...  ...        ...    ...
# 395        138     108           17         203    128   33         14      1
# 396        139      23            3          37    120   55         11      0
# 397        162      26           12         368    159   40         18      1
# 398        100      79            7         284     95   50         12      1
# 399        134      37            0          27    120   49         16      1
#
# ...

# %%
dff.corr()
# Out:
#                   CompPrice    Income  Advertising  Population     Price  \
# CompPrice          1.000000 -0.077315    -0.021957   -0.096309  0.585053
# Income            -0.077315  1.000000     0.055241   -0.005362 -0.045616
# Advertising       -0.021957  0.055241     1.000000    0.267706  0.052495
# Population        -0.096309 -0.005362     0.267706    1.000000 -0.016978
# Price              0.585053 -0.045616     0.052495   -0.016978  1.000000
# Age               -0.104320  0.001695    -0.000587   -0.045347 -0.115424
# Education          0.024263 -0.055362    -0.032590   -0.107122  0.008760
# Urban              0.070427  0.031975     0.038327   -0.049747  0.059169
# US                 0.020029  0.084668     0.683497    0.062877  0.068644
# ShelveLoc_Bad     -0.034152  0.070019    -0.036684    0.040831 -0.032462
# ShelveLoc_Good     0.027617 -0.014789     0.054936    0.008620  0.050222
# ShelveLoc_Medium   0.006610 -0.047955    -0.013685   -0.042147 -0.013434
#
# ...

# %%
# US and advertisement column have some multicollinarity problems

# %% [markdown]
# # Split features and target

# %%
X=dff.iloc[:,0:12]
y=dff["ysales"].values

# %%
y
# Out:
# [1, 1, 1, 0, 0, ..., 1, 0, 0, 0, 1]
# Length: 399
# Categories (2, int64): [0 < 1]

# %%
from sklearn.preprocessing import StandardScaler # standarization is not required for decision tree

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(X)

# %% [markdown]
# # Train and test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test= train_test_split(x,y,train_size=0.75,random_state=0)

# %% [markdown]
# # Model Creation

# %%
from sklearn.tree import DecisionTreeClassifier
model= DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Model Validation: Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

y_pred = model.predict(X_test)

cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[57, 11],
#        [14, 18]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82        68
#            1       0.62      0.56      0.59        32
#
#     accuracy                           0.75       100
#    macro avg       0.71      0.70      0.71       100
# weighted avg       0.74      0.75      0.75       100

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.75

# %%
y_pred1 = model.predict(X_train)
accuracy_score(y_train,y_pred1)
# Out:
# 1.0

# %% [markdown]
# # Model Visualization & Tree  Visualization

# %%
from sklearn import tree
plt.figure(figsize=(25,15))
tree.plot_tree(model,filled=True)

plt.show()

# %% [markdown]
# # K-Fold Testing: help us to find out stability of the accuracy

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
fold = KFold(n_splits=5,shuffle=False)

# %%
model1 = DecisionTreeClassifier()

results = cross_val_score(model,X,y,cv = fold)

# %%
results.min(),results.max()
# Out:
# (0.7215189873417721, 0.8)

# %%
results.std()
# Out:
# 0.030663168967032528

# %%
results.mean()
# Out:
# 0.7518037974683545

# %% [markdown]
# # Pruning tree

# %%
model2 = DecisionTreeClassifier(criterion="gini",max_depth=None,ccp_alpha=0.0)

# %%
path = model2.cost_complexity_pruning_path(X_train,y_train)

# %%
ccp_alphas = path.ccp_alphas

# %%
ccp_alphas
# Out:
# array([0.        , 0.00304044, 0.00313545, 0.00317297, 0.00387721,
#        0.00401338, 0.00445931, 0.00445931, 0.00445931, 0.00448837,
#        0.00553315, 0.00594575, 0.00622751, 0.00648627, 0.01003344,
#        0.01055466, 0.01146679, 0.01170569, 0.01170569, 0.0134286 ,
#        0.02136979, 0.02322026, 0.02924792, 0.03181569, 0.07215792])

# %%
len(ccp_alphas)
# Out:
# 25

# %%
train_score = []
test_score = []

for i in ccp_alphas:
    model1 = DecisionTreeClassifier(ccp_alpha=i)
    model1.fit(X_train,y_train)
    train_score.append(model1.score(X_train,y_train))
    test_score.append(model1.score(X_test,y_test))    
train_score
# Out:
# [1.0,
#  0.9933110367892977,
#  0.9899665551839465,
#  0.9832775919732442,
#  0.9765886287625418,
#  0.9698996655518395,
#  0.959866220735786,
#  0.959866220735786,
#  0.959866220735786,
#  0.9565217391304348,
#  0.9531772575250836,
#  0.9498327759197325,
#  0.9464882943143813,
#  0.9431438127090301,
#  0.9364548494983278,
#  0.9264214046822743,
#  0.919732441471572,
#  0.8929765886287625,
#  0.8929765886287625,
#  0.8695652173913043,
#  0.8327759197324415,
#  0.8127090301003345,
#  0.8127090301003345,
#  0.7892976588628763,
#  0.7290969899665551]

# %%
model1.score(X_test,y_test) # model.score() gives accuracy of dataset similar to accuraccy_score()
# Out:
# 0.68

# %%
plt.scatter(ccp_alphas,train_score,color="green",label="Training")
plt.plot(ccp_alphas,train_score,color="green",label="Training")
plt.scatter(ccp_alphas,test_score,color = "red",label="Test")
plt.plot(ccp_alphas,test_score,color = "red",label="Test")
plt.xlabel("CCP alpha")
plt.ylabel("Accuracy")

plt.legend()
plt.show()

# %%
plt.scatter(ccp_alphas,train_score,color="green",label="Training")
plt.plot(ccp_alphas,train_score,color="green",label="Training")
plt.scatter(ccp_alphas,test_score,color = "red",label="Test")
plt.plot(ccp_alphas,test_score,color = "red",label="Test")
plt.xlabel("CCP alpha")
plt.ylabel("Accuracy")
plt.xlim(0.02,0.04)
plt.legend()
plt.grid()
plt.show()

# %%
ccp_alphas
# Out:
# array([0.        , 0.00304044, 0.00313545, 0.00317297, 0.00387721,
#        0.00401338, 0.00445931, 0.00445931, 0.00445931, 0.00448837,
#        0.00553315, 0.00594575, 0.00622751, 0.00648627, 0.01003344,
#        0.01055466, 0.01146679, 0.01170569, 0.01170569, 0.0134286 ,
#        0.02136979, 0.02322026, 0.02924792, 0.03181569, 0.07215792])

# %%
# at ccp_alphas 0.02322026 training and testing accuraccy is nearly equal

# %% [markdown]
# # Final model

# %%
final_model = DecisionTreeClassifier(ccp_alpha=0.00384921,max_depth=None,criterion="gini")
final_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.00384921)

# %%
y_pred = final_model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.78

# %%
y_pred1 = final_model.predict(X_train)
accuracy_score(y_train,y_pred1)
# Out:
# 0.9832775919732442

# %%
final_model.score(X_test,y_test)
# Out:
# 0.78

# %%
from sklearn import tree
plt.figure(figsize=(35,20))
tree.plot_tree(final_model,filled=True)

plt.show()

# %%
X
# Out:
#      CompPrice  Income  Advertising  Population  Price  Age  Education  Urban  \
# 0          138      73           11         276    120   42         17      1
# 1          111      48           16         260     83   65         10      1
# 2          113      35           10         269     80   59         12      1
# 3          117     100            4         466     97   55         14      1
# 4          141      64            3         340    128   38         13      1
# ..         ...     ...          ...         ...    ...  ...        ...    ...
# 395        138     108           17         203    128   33         14      1
# 396        139      23            3          37    120   55         11      0
# 397        162      26           12         368    159   40         18      1
# 398        100      79            7         284     95   50         12      1
# 399        134      37            0          27    120   49         16      1
#
# ...
