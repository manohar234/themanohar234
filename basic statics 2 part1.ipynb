# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("factory q1.csv")
df
# Out:
#      Name of company  Measure X in%
# 0      Allied Signal          24.23
# 1      Bankers Trust          25.53
# 2      General Mills          25.41
# 3     ITT Industries          24.14
# 4   J.P.Morgan & Co.          29.62
# 5    Lehman Brothers          28.25
# 6           Marriott          25.81
# 7                MCI          24.39
# 8      Merrill Lynch          40.26
# 9          Microsoft          32.95
# 10    Morgan Stanley          91.36
# 11  Sun Microsystems          25.99
# 12         Travelers          39.42
# 13        US Airways          26.71
# 14    Warner-Lambert          35.00

# %%
plt.rcParams ["figure.figsize"] = (32,10)

# %%
plt.bar(df.iloc[:,0],df.iloc[:,1])
fig=plt.figure(figsize=(15,8))

# %%
#0.3327133, 0.169454, 0.02871466

# %%
df["Measure X in%"].mean()
# Out:
# 33.27133333333333

# %%
df["Measure X in%"].std()
# Out:
# 16.945400921222028

# %%
# variance= 289

# %%
import seaborn as sns

# %%
sns.boxplot(df["Measure X in%"])
# Out:
# D:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Measure X in%'>

# %%
df1 = df[["Measure X in%"]]
df1
# Out:
#     Measure X in%
# 0           24.23
# 1           25.53
# 2           25.41
# 3           24.14
# 4           29.62
# 5           28.25
# 6           25.81
# 7           24.39
# 8           40.26
# 9           32.95
# 10          91.36
# 11          25.99
# 12          39.42
# 13          26.71
# 14          35.00

# %% [markdown]
# df2

# %%
df1
# Out:
#     Measure X in%
# 0           24.23
# 1           25.53
# 2           25.41
# 3           24.14
# 4           29.62
# 5           28.25
# 6           25.81
# 7           24.39
# 8           40.26
# 9           32.95
# 10          91.36
# 11          25.99
# 12          39.42
# 13          26.71
# 14          35.00

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df1 = sc.fit_transform(df1)
df1
# Out:
# array([[-0.55228372],
#        [-0.4728741 ],
#        [-0.48020422],
#        [-0.55778131],
#        [-0.22303922],
#        [-0.30672475],
#        [-0.45577049],
#        [-0.54251023],
#        [ 0.42689797],
#        [-0.01962843],
#        [ 3.54830686],
#        [-0.44477532],
#        [ 0.37558714],
#        [-0.4007946 ],
#        [ 0.10559443]])

# %%
out = []
for var in df1[:,0]:
    if var>3 or var<-3:
        out.append(var)

# %%
out
# Out:
# [3.5483068628299663]

# %%
for i in out:
    measure = i*16.94028971+33.276502
    print(measure)
# Out:
# 93.38584823632085

# %%
# so morgan stainley 91 is the outlier
